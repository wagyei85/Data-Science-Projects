# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
df=pd.read_excel('Maison.xlsx')

# %%
df
# Out:
#        PRIX  SUPERFICIE  CHAMBRES  SDB  ETAGES  ALLEE  SALLEJEU  CAVE  GAZ  \
# 0     42000        5850         3    1       2      1         0     1    0
# 1     38500        4000         2    1       1      1         0     0    0
# 2     49500        3060         3    1       1      1         0     0    0
# 3     60500        6650         3    1       2      1         1     0    0
# 4     61000        6360         2    1       1      1         0     0    0
# ..      ...         ...       ...  ...     ...    ...       ...   ...  ...
# 541   91500        4800         3    2       4      1         1     0    0
# 542   94000        6000         3    2       4      1         0     0    0
# 543  103000        6000         3    2       4      1         1     0    0
# 544  105000        6000         3    2       2      1         1     0    0
# 545  105000        6000         3    1       2      1         0     0    0
#
#      AIR  GARAGES  SITUATION
# 0      0        1          0
# ...

# %%
df.head(20)
# Out:
#      PRIX  SUPERFICIE  CHAMBRES  SDB  ETAGES  ALLEE  SALLEJEU  CAVE  GAZ  AIR  \
# 0   42000        5850         3    1       2      1         0     1    0    0
# 1   38500        4000         2    1       1      1         0     0    0    0
# 2   49500        3060         3    1       1      1         0     0    0    0
# 3   60500        6650         3    1       2      1         1     0    0    0
# 4   61000        6360         2    1       1      1         0     0    0    0
# 5   66000        4160         3    1       1      1         1     1    0    1
# 6   66000        3880         3    2       2      1         0     1    0    0
# 7   69000        4160         3    1       3      1         0     0    0    0
# 8   83800        4800         3    1       1      1         1     1    0    0
# 9   88500        5500         3    2       4      1         1     0    0    1
# 10  90000        7200         3    2       1      1         0     1    0    1
# ...

# %%
df.shape
# Out:
# (546, 12)

# %%
df.columns
# Out:
# Index(['PRIX', 'SUPERFICIE', 'CHAMBRES', 'SDB', 'ETAGES', 'ALLEE', 'SALLEJEU',
#        'CAVE', 'GAZ', 'AIR', 'GARAGES', 'SITUATION'],
#       dtype='object')

# %%
df.dtypes
# Out:
# PRIX          int64
# SUPERFICIE    int64
# CHAMBRES      int64
# SDB           int64
# ETAGES        int64
# ALLEE         int64
# SALLEJEU      int64
# CAVE          int64
# GAZ           int64
# AIR           int64
# GARAGES       int64
# SITUATION     int64
# dtype: object

# %%
df.info
# Out:
# <bound method DataFrame.info of        PRIX  SUPERFICIE  CHAMBRES  SDB  ETAGES  ALLEE  SALLEJEU  CAVE  GAZ  \
# 0     42000        5850         3    1       2      1         0     1    0
# 1     38500        4000         2    1       1      1         0     0    0
# 2     49500        3060         3    1       1      1         0     0    0
# 3     60500        6650         3    1       2      1         1     0    0
# 4     61000        6360         2    1       1      1         0     0    0
# ..      ...         ...       ...  ...     ...    ...       ...   ...  ...
# 541   91500        4800         3    2       4      1         1     0    0
# 542   94000        6000         3    2       4      1         0     0    0
# 543  103000        6000         3    2       4      1         1     0    0
# 544  105000        6000         3    2       2      1         1     0    0
# 545  105000        6000         3    1       2      1         0     0    0
#
#      AIR  GARAGES  SITUATION
# ...

# %%
df.isnull().sum()
# Out:
# PRIX          0
# SUPERFICIE    0
# CHAMBRES      0
# SDB           0
# ETAGES        0
# ALLEE         0
# SALLEJEU      0
# CAVE          0
# GAZ           0
# AIR           0
# GARAGES       0
# SITUATION     0
# dtype: int64

# %%
df.describe()
# Out:
#                 PRIX    SUPERFICIE    CHAMBRES         SDB      ETAGES  \
# count     546.000000    546.000000  546.000000  546.000000  546.000000
# mean    68121.597070   5150.265568    2.965201    1.285714    1.807692
# std     26702.670926   2168.158725    0.737388    0.502158    0.868203
# min     25000.000000   1650.000000    1.000000    1.000000    1.000000
# 25%     49125.000000   3600.000000    2.000000    1.000000    1.000000
# 50%     62000.000000   4600.000000    3.000000    1.000000    2.000000
# 75%     82000.000000   6360.000000    3.000000    2.000000    2.000000
# max    190000.000000  16200.000000    6.000000    4.000000    4.000000
#
#             ALLEE    SALLEJEU        CAVE         GAZ         AIR     GARAGES  \
# count  546.000000  546.000000  546.000000  546.000000  546.000000  546.000000
# mean     0.858974    0.177656    0.349817    0.045788    0.316850    0.692308
# std      0.348367    0.382573    0.477349    0.209216    0.465675    0.861307
# ...

# %%
# The columns names are in French so we will change it to english

# %%
df=df.rename(index=str,columns={'PRIX':'price','SUPERFICIE':'area','CHAMBRES':'rooms','SDB':'bathrom','ETAGES':'floor','ALLEE':'driveway','SALLEJEU':'game_room','CAVE':'cellar','GAZ':'gas','AIR':'air','GARAGES':'garage','SITUATION':'situation'})

# %%
df.head(20)
# Out:
#     price  area  rooms  bathrom  floor  driveway  game_room  cellar  gas  air  \
# 0   42000  5850      3        1      2         1          0       1    0    0
# 1   38500  4000      2        1      1         1          0       0    0    0
# 2   49500  3060      3        1      1         1          0       0    0    0
# 3   60500  6650      3        1      2         1          1       0    0    0
# 4   61000  6360      2        1      1         1          0       0    0    0
# 5   66000  4160      3        1      1         1          1       1    0    1
# 6   66000  3880      3        2      2         1          0       1    0    0
# 7   69000  4160      3        1      3         1          0       0    0    0
# 8   83800  4800      3        1      1         1          1       1    0    0
# 9   88500  5500      3        2      4         1          1       0    0    1
# 10  90000  7200      3        2      1         1          0       1    0    1
# ...

# %%
sns.scatterplot(df.area,df.price,df.gas,palette='viridis')

# %%
sns.distplot(df.price)

# %%
sns.distplot(df.area)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
lm=LinearRegression()

# %%
x=df[['area','rooms','bathrom','floor','driveway','game_room','cellar','gas','air','garage','situation']]
y=df['price']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=101)

# %%
x_train.head()
# Out:
#      area  rooms  bathrom  floor  driveway  game_room  cellar  gas  air  \
# 227  3185      2        1      1         1          0       1    0    0
# 319  5200      3        1      3         1          0       0    0    1
# 367  7950      5        2      2         1          0       1    1    0
# 515  3584      2        1      1         1          0       0    1    0
# 143  4500      2        1      1         0          0       0    0    0
#
#      garage  situation
# 227       2          0
# 319       0          0
# 367       2          0
# 515       0          0
# 143       0          0

# %%
lm.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
pred=lm.predict(x_test)

# %%
lm.intercept_
# Out:
# -4908.338812658971

# %%
lm.coef_
# Out:
# array([3.89376339e+00, 2.55486255e+03, 1.41206688e+04, 6.16725062e+03,
#        4.75380710e+03, 4.38194457e+03, 3.74440604e+03, 1.42141371e+04,
#        1.29601437e+04, 5.04155805e+03, 9.99613065e+03])

# %%
results=pd.DataFrame(lm.coef_,x.columns, columns=['Coefficients'])

# %%
results
# Out:
#            Coefficients
# area           3.893763
# rooms       2554.862552
# bathrom    14120.668799
# floor       6167.250616
# driveway    4753.807097
# game_room   4381.944571
# cellar      3744.406037
# gas        14214.137067
# air        12960.143692
# garage      5041.558049
# situation   9996.130651

# %%
import statsmodels.api as sm

# %%
x_const=sm.add_constant(x_test)

# %%
res=sm.OLS(y_test,x_const)

# %%
res.fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.681
# Model:                            OLS   Adj. R-squared:                  0.657
# Method:                 Least Squares   F-statistic:                     29.45
# Date:                Wed, 04 Dec 2019   Prob (F-statistic):           2.53e-32
# Time:                        13:41:25   Log-Likelihood:                -1795.1
# No. Observations:                 164   AIC:                             3614.
# Df Residuals:                     152   BIC:                             3651.
# Df Model:                          11
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -703.0200   5457.714     -0.129      0.898   -1.15e+04    1.01e+04
# ...

# %%
sns.regplot(y_test,pred)

# %%
sns.distplot(y_test-pred)

# %%
from sklearn import  metrics

# %%
print('MAE:',metrics.mean_absolute_error(y_test,pred))
print('MSE:',metrics.mean_squared_error(y_test,pred))
print('RMSE:',np.sqrt(metrics.mean_squared_error(y_test,pred)))
# Out:
# MAE: 11245.248764945301
# MSE: 220851427.29447812
# RMSE: 14861.070866343318

# %%
sns.pairplot(df)

# %%
sns.heatmap(df.corr(),annot=True)
