# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve

# %%
df=pd.read_csv('pulsar_stars.csv')

# %%
df.head()
# Out:
#     Mean of the integrated profile  \
# 0                       140.562500
# 1                       102.507812
# 2                       103.015625
# 3                       136.750000
# 4                        88.726562
#
#     Standard deviation of the integrated profile  \
# 0                                      55.683782
# 1                                      58.882430
# 2                                      39.341649
# 3                                      57.178449
# 4                                      40.672225
#
#     Excess kurtosis of the integrated profile  \
# 0                                   -0.234571
# 1                                    0.465318
# 2                                    0.323328
# 3                                   -0.068415
# 4                                    0.600866
#
#     Skewness of the integrated profile   Mean of the DM-SNR curve  \
# 0                            -0.699648                   3.199833
# ...

# %%
df.tail()
# Out:
#         Mean of the integrated profile  \
# 17893                       136.429688
# 17894                       122.554688
# 17895                       119.335938
# 17896                       114.507812
# 17897                        57.062500
#
#         Standard deviation of the integrated profile  \
# 17893                                      59.847421
# 17894                                      49.485605
# 17895                                      59.935939
# 17896                                      53.902400
# 17897                                      85.797340
#
#         Excess kurtosis of the integrated profile  \
# 17893                                   -0.187846
# 17894                                    0.127978
# 17895                                    0.159363
# 17896                                    0.201161
# 17897                                    1.406391
#
#         Skewness of the integrated profile   Mean of the DM-SNR curve  \
# ...

# %%
df.shape
# Out:
# (17898, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17898 entries, 0 to 17897
# Data columns (total 9 columns):
#  Mean of the integrated profile                  17898 non-null float64
#  Standard deviation of the integrated profile    17898 non-null float64
#  Excess kurtosis of the integrated profile       17898 non-null float64
#  Skewness of the integrated profile              17898 non-null float64
#  Mean of the DM-SNR curve                        17898 non-null float64
#  Standard deviation of the DM-SNR curve          17898 non-null float64
#  Excess kurtosis of the DM-SNR curve             17898 non-null float64
#  Skewness of the DM-SNR curve                    17898 non-null float64
# target_class                                     17898 non-null int64
# dtypes: float64(8), int64(1)
# memory usage: 1.2 MB

# %%
df.columns
# Out:
# Index([' Mean of the integrated profile',
#        ' Standard deviation of the integrated profile',
#        ' Excess kurtosis of the integrated profile',
#        ' Skewness of the integrated profile', ' Mean of the DM-SNR curve',
#        ' Standard deviation of the DM-SNR curve',
#        ' Excess kurtosis of the DM-SNR curve', ' Skewness of the DM-SNR curve',
#        'target_class'],
#       dtype='object')

# %%
sns.heatmap(df.isnull())

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#         Mean of the integrated profile  \
# count                     17898.000000
# mean                        111.079968
# std                          25.652935
# min                           5.812500
# 25%                         100.929688
# 50%                         115.078125
# 75%                         127.085938
# max                         192.617188
#
#         Standard deviation of the integrated profile  \
# count                                   17898.000000
# mean                                       46.549532
# std                                         6.843189
# min                                        24.772042
# 25%                                        42.376018
# 50%                                        46.947479
# 75%                                        51.023202
# max                                        98.778911
#
#         Excess kurtosis of the integrated profile  \
# count                                17898.000000
# ...

# %%
### Exploratory Data Analysis

# %%
sns.countplot(df.target_class)

# %%
sns.set()
df.hist(figsize=(12,8))
plt.show()

# %%
sns.pairplot(df,vars=[' Mean of the integrated profile',
       ' Standard deviation of the integrated profile',
       ' Excess kurtosis of the integrated profile',
       ' Skewness of the integrated profile', ' Mean of the DM-SNR curve',
       ' Standard deviation of the DM-SNR curve',
       ' Excess kurtosis of the DM-SNR curve', ' Skewness of the DM-SNR curve',],hue='target_class',palette='husl')

# %%
plt.figure(figsize=(12,8))
plt.subplot(2,2,1)
sns.violinplot(data=df,x='target_class',y=' Mean of the integrated profile')
plt.subplot(2,2,2)
sns.violinplot(data=df,x='target_class',y=' Standard deviation of the integrated profile')
plt.subplot(2,2,3)
sns.violinplot(data=df,x='target_class',y=' Standard deviation of the DM-SNR curve')
plt.subplot(2,2,4)
sns.violinplot(data=df,x='target_class',y=' Mean of the DM-SNR curve')

# %%
plt.figure(figsize=(12,8))
sns.heatmap(df.corr(),annot=True)

# %%
### Model

# %%
y=df.target_class
x=df.drop('target_class',axis=1)
x.shape,y.shape
# Out:
# ((17898, 8), (17898,))

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=42)

# %%
ss=StandardScaler()
x_train=ss.fit_transform(x_train)
x_test=ss.fit_transform(x_test)

# %%
svm=SVC(probability=True)
svm.fit(x_train,y_train)
prediction=svm.predict(x_test)

# %%
print(classification_report(y_test,prediction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99      3259
#            1       0.94      0.82      0.88       321
#
#     accuracy                           0.98      3580
#    macro avg       0.96      0.91      0.93      3580
# weighted avg       0.98      0.98      0.98      3580

# %%
cm=confusion_matrix(y_test,prediction)
fig,ax=plt.subplots(figsize=(5,5))
ax.matshow(cm,cmap=plt.cm.Blues,alpha=0.7)
for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        ax.text(x=j,y=i,s=cm[i,j],va='center',ha='center')
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
print('Accuracy Score: ',round(accuracy_score(y_test,prediction)*100,2))
# Out:
# Accuracy Score:  97.91

# %%
auc=roc_auc_score(y_test,prediction)
fpr,tpr,thr=roc_curve(y_test,svm.predict_proba(x_test)[:,1])
plt.plot(fpr,tpr,label='AUC(area=%0.3f)'%auc)
plt.plot([0,1],[0,1],'r--')
plt.title('Reciever Operatining Characteristic')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.show()
