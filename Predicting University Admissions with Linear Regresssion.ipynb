# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
df=pd.read_csv('admission.csv')

# %%
df.head(20)
# Out:
#     Serial_No.  GRE  TOEFL_Score  UniversityRating  SOP  LOR   CGPA  Research  \
# 0            1  337          118                 4  4.5   4.5  9.65         1
# 1            2  324          107                 4  4.0   4.5  8.87         1
# 2            3  316          104                 3  3.0   3.5  8.00         1
# 3            4  322          110                 3  3.5   2.5  8.67         1
# 4            5  314          103                 2  2.0   3.0  8.21         0
# 5            6  330          115                 5  4.5   3.0  9.34         1
# 6            7  321          109                 3  3.0   4.0  8.20         1
# 7            8  308          101                 2  3.0   4.0  7.90         0
# 8            9  302          102                 1  2.0   1.5  8.00         0
# 9           10  323          108                 3  3.5   3.0  8.60         0
# 10          11  325          106                 3  3.5   4.0  8.40         1
# ...

# %%
df.columns
# Out:
# Index(['Serial_No.', 'GRE', 'TOEFL_Score', 'UniversityRating', 'SOP', 'LOR ',
#        'CGPA', 'Research', 'Chance'],
#       dtype='object')

# %%
df=df.drop('Serial_No.',axis=1)

# %%
df.info
# Out:
# <bound method DataFrame.info of      GRE  TOEFL_Score  UniversityRating  SOP  LOR   CGPA  Research  Chance
# 0    337          118                 4  4.5   4.5  9.65         1    0.92
# 1    324          107                 4  4.0   4.5  8.87         1    0.76
# 2    316          104                 3  3.0   3.5  8.00         1    0.72
# 3    322          110                 3  3.5   2.5  8.67         1    0.80
# 4    314          103                 2  2.0   3.0  8.21         0    0.65
# ..   ...          ...               ...  ...   ...   ...       ...     ...
# 395  324          110                 3  3.5   3.5  9.04         1    0.82
# 396  325          107                 3  3.0   3.5  9.11         1    0.84
# 397  330          116                 4  5.0   4.5  9.45         1    0.91
# 398  312          103                 3  3.5   4.0  8.78         0    0.67
# 399  333          117                 4  5.0   4.0  9.66         1    0.95
#
# [400 rows x 8 columns]>

# %%
df.describe()
# Out:
#               GRE  TOEFL_Score  UniversityRating         SOP        LOR   \
# count  400.000000   400.000000        400.000000  400.000000  400.000000
# mean   316.807500   107.410000          3.087500    3.400000    3.452500
# std     11.473646     6.069514          1.143728    1.006869    0.898478
# min    290.000000    92.000000          1.000000    1.000000    1.000000
# 25%    308.000000   103.000000          2.000000    2.500000    3.000000
# 50%    317.000000   107.000000          3.000000    3.500000    3.500000
# 75%    325.000000   112.000000          4.000000    4.000000    4.000000
# max    340.000000   120.000000          5.000000    5.000000    5.000000
#
#              CGPA    Research      Chance
# count  400.000000  400.000000  400.000000
# mean     8.598925    0.547500    0.724350
# std      0.596317    0.498362    0.142609
# min      6.800000    0.000000    0.340000
# 25%      8.170000    0.000000    0.640000
# 50%      8.610000    1.000000    0.730000
# ...

# %%
df.shape
# Out:
# (400, 8)

# %%
#.

# %%
df
# Out:
#      GRE  TOEFL_Score  UniversityRating  SOP  LOR   CGPA  Research  Chance
# 0    337          118                 4  4.5   4.5  9.65         1    0.92
# 1    324          107                 4  4.0   4.5  8.87         1    0.76
# 2    316          104                 3  3.0   3.5  8.00         1    0.72
# 3    322          110                 3  3.5   2.5  8.67         1    0.80
# 4    314          103                 2  2.0   3.0  8.21         0    0.65
# ..   ...          ...               ...  ...   ...   ...       ...     ...
# 395  324          110                 3  3.5   3.5  9.04         1    0.82
# 396  325          107                 3  3.0   3.5  9.11         1    0.84
# 397  330          116                 4  5.0   4.5  9.45         1    0.91
# 398  312          103                 3  3.5   4.0  8.78         0    0.67
# 399  333          117                 4  5.0   4.0  9.66         1    0.95
#
# [400 rows x 8 columns]

# %%
df.dtypes
# Out:
# GRE                   int64
# TOEFL_Score           int64
# UniversityRating      int64
# SOP                 float64
# LOR                 float64
# CGPA                float64
# Research              int64
# Chance              float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# GRE                 0
# TOEFL_Score         0
# UniversityRating    0
# SOP                 0
# LOR                 0
# CGPA                0
# Research            0
# Chance              0
# dtype: int64

# %%
df.columns
# Out:
# Index(['GRE', 'TOEFL_Score', 'UniversityRating', 'SOP', 'LOR ', 'CGPA',
#        'Research', 'Chance'],
#       dtype='object')

# %%
df.Chance.describe()
# Out:
# count    400.000000
# mean       0.724350
# std        0.142609
# min        0.340000
# 25%        0.640000
# 50%        0.730000
# 75%        0.830000
# max        0.970000
# Name: Chance, dtype: float64

# %%
sns.distplot(df.Chance)

# %%
sns.regplot(df.GRE,df.Chance)

# %%
sns.regplot(df.SOP,df.Chance)

# %%
sns.regplot(df['TOEFL_Score'],df.Chance)

# %%
sns.pairplot(df)

# %%
# %matplotlib inline
sns.heatmap(df.corr(),annot=True)

# %%
x=df[['GRE', 'TOEFL_Score', 'UniversityRating', 'SOP', 'LOR ','CGPA', 'Research']]
y=df['Chance']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.7,random_state=100)

# %%
x_train.shape
# Out:
# (280, 7)

# %%
y_train
# Out:
# 234    0.91
# 45     0.88
# 171    0.89
# 47     0.89
# 265    0.71
#        ...
# 343    0.59
# 359    0.81
# 323    0.62
# 280    0.68
# 8      0.50
# Name: Chance, Length: 280, dtype: float64

# %%
from sklearn.linear_model import LinearRegression
lm=LinearRegression()

# %%
lm.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
pred=lm.predict(x_test)

# %%
lm.intercept_
# Out:
# -1.2282853981310136

# %%
results=pd.DataFrame(lm.coef_,x.columns,columns=['Coefficients'])

# %%
results
# Out:
#                   Coefficients
# GRE                   0.001210
# TOEFL_Score           0.003405
# UniversityRating      0.006827
# SOP                  -0.010078
# LOR                   0.027240
# CGPA                  0.128798
# Research              0.023014

# %%
sns.regplot(y_test,pred)

# %%
sns.distplot(y_test-pred)

# %%
from sklearn import metrics

# %%
print('MAE:', metrics.mean_absolute_error(y_test,pred))
print('MSE:',metrics.mean_squared_error(y_test,pred))
print('RMSE:',np.sqrt(metrics.mean_squared_error(y_test,pred)))
# Out:
# MAE: 0.046928782854889314
# MSE: 0.003716513784197384
# RMSE: 0.060963216649036686

# %%
print('R-squared:',metrics.r2_score(y_test,pred))
# Out:
# R-squared: 0.8003159611553707
